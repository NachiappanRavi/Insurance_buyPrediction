# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance, marker ='+', color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 18   19
# 20   21
# 15   55
# 4    46
# 23   45
# 7    60

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 18   19
# 20   21
# 15   55
# 4    46
# 23   45
# 7    60

# %%
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([0, 0, 1, 1, 1, 1], dtype=int64)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.92606433, 0.07393567],
#        [0.90841947, 0.09158053],
#        [0.15829807, 0.84170193],
#        [0.34949209, 0.65050791],
#        [0.37645037, 0.62354963],
#        [0.09499655, 0.90500345]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([0, 0, 1, 1, 1, 1], dtype=int64)

# %%
X_test
# Out:
#     age
# 18   19
# 20   21
# 15   55
# 4    46
# 23   45
# 7    60

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[2, 0],
#        [0, 4]], dtype=int64)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.8.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\naach\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
